# %% [markdown]
# <a href="https://colab.research.google.com/github/TzuyusForgottenLuggage/DeepLearing_Workshop/blob/main/Workshop_Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model=hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %%
def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

# %%
content_image = load_image('/content/baby_yoda.jpeg')
style_image = load_image('/content/monet.jpeg')

# %%
plt.imshow(np.squeeze(content_image))

# %%
plt.imshow(np.squeeze(style_image))

# %%
final_image = model(content_image,style_image)[0]

# %%
plt.imshow(np.squeeze(final_image))

# %%
cv2.imwrite('generated_img_yoda.jpg', cv2.cvtColor(np.squeeze(final_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image_2 = load_image('/content/panda.jpeg')
style_image_2 = load_image('/content/starry_night.jpeg')

# %%
plt.imshow(np.squeeze(content_image_2))

# %%
plt.imshow(np.squeeze(style_image_2))

# %%
final_image_2 = model(content_image_2,style_image_2)[0]

# %%
plt.imshow(np.squeeze(final_image_2))

# %%
cv2.imwrite('generated_img.jpg', cv2.cvtColor(np.squeeze(final_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True
